# %% [markdown]
# # Data Analysis

# %% [markdown]
# The Following document conducts a detailed analysis on the data collected as of 19/02/2026.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Research Study_ Public Perception and Technical Understanding of Generative AI (Responses) - Form Responses 1.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'
